# %% [markdown]
# <a href="https://colab.research.google.com/github/DChristianls/Calorie-calculator/blob/main/Ex1_M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
#a -
#b -
#c -
#d -

#Q2
#a -
#b -
#c -

#Q3
#a -
import pandas as pd
import matplotlib . pyplot as plt
url = (’https :// raw . githubusercontent .com / stedy /’
’Machine - Learning -with -R- datasets / master / insurance .
csv ’)
df = pd . read_csv ( url )
fumantes = df [ df [’smoker ’] == ’yes ’]
nao_fumantes = df [ df [’smoker ’] == ’no ’]
# (a-i) Calcule a correlacao de Pearson entre ’bmi ’ e ’
charges ’
correlacao = ________________________________________
print (f" Correlacao entre IMC e Custo : { correlacao :.4 f}")
# (a-ii) Complete o scatter plot
plt . figure ( figsize =(8 , 5) )
plt . scatter ( _________________________ ,
_________________________ , label =’Fumante ’,
alpha =0.6 , color =’tomato ’, s =20)
plt . scatter ( _________________________ ,
_________________________ , label =’Nao Fumante ’,
alpha =0.6 , color =’steelblue ’, s =20)
plt . xlabel (’IMC (bmi )’)
plt . ylabel (’Custo do Seguro (US$ )’)
plt . title (’IMC vs Custo do Seguro por Habito de Fumar ’)
plt . legend ()
plt . tight_layout ()
plt . show ()

#b -
#c -

#Q4
#a -
#b -
#c -


#Q5
import pandas as pd
import numpy as np
url = (’https :// raw . githubusercontent .com / stedy /’
’Machine - Learning -with -R- datasets / master / insurance .
csv ’)
df = pd . read_csv ( url )
# --- Simulacao de dados faltantes ( execute sem alteracoes )
---
np . random . seed (42)
idx_bmi = np . random . choice ( df . index , size =40 , replace =
False )
idx_charges = np . random . choice ( df . index , size =16 , replace =
False )
df . loc [ idx_bmi , ’bmi ’] = np . nan
df . loc [ idx_charges , ’charges ’] = np . nan

#a -
#b -
df [’bmi ’] = ________________________________________

#c -
df [’charges ’] = ________________________________________
print ( df [[ ’bmi ’, ’charges ’]]. isnull () . sum () )

#d-
